# %%
import pandas as pd

# %%
# reading csv file
df_population_raw = pd.read_csv('population_total.csv')

# %%
df_population_raw
# Out:
#             country    year    population
# 0             China  2020.0  1.439324e+09
# 1             China  2019.0  1.433784e+09
# 2             China  2018.0  1.427648e+09
# 3             China  2017.0  1.421022e+09
# 4             China  2016.0  1.414049e+09
# ...             ...     ...           ...
# 4180  United States  1965.0  1.997337e+08
# 4181  United States  1960.0  1.867206e+08
# 4182  United States  1955.0  1.716853e+08
# 4183          India  1960.0  4.505477e+08
# 4184          India  1955.0  4.098806e+08
#
# [4185 rows x 3 columns]

# %%
df_population_raw.dropna(inplace=True)

# %%
df_population = df_population_raw.pivot(
                index='year',
                columns='country',
                values='population'
)

# %%
df_population = df_population[['United States','India','Brazil','China','Spain']]
df_population
# Out:
# country  United States         India       Brazil         China       Spain
# year
# 1955.0     171685336.0  4.098806e+08   62533919.0  6.122416e+08  29048395.0
# 1960.0     186720571.0  4.505477e+08   72179226.0  6.604081e+08  30402411.0
# 1965.0     199733676.0  4.991233e+08   83373530.0  7.242190e+08  32146263.0
# 1970.0     209513341.0  5.551898e+08   95113265.0  8.276014e+08  33883749.0
# 1975.0     219081251.0  6.231029e+08  107216205.0  9.262409e+08  35879209.0
# 1980.0     229476354.0  6.989528e+08  120694009.0  1.000089e+09  37698196.0
# 1985.0     240499825.0  7.843600e+08  135274080.0  1.075589e+09  38733876.0
# 1990.0     252120309.0  8.732778e+08  149003223.0  1.176884e+09  39202525.0
# 1995.0     265163745.0  9.639226e+08  162019896.0  1.240921e+09  39787419.0
# 2000.0     281710909.0  1.056576e+09  174790340.0  1.290551e+09  40824754.0
# 2005.0     294993511.0  1.147610e+09  186127103.0  1.330776e+09  44019123.0
# ...

# %% [markdown]
# ### Lineplot

# %%
df_population_line = df_population.head()
df_population_line.plot(kind='line')
# Out:
# <Axes: xlabel='year'>

# %%
# with label parameters
df_population_line.plot(kind='line', xlabel='Year', ylabel='Population', title='Population Per country')
# Out:
# <Axes: title={'center': 'Population Per country'}, xlabel='Year', ylabel='Population'>

# %%
# with figsize parameter (to adjust the size)
df_population.plot(kind='line',figsize=(10,6), xlabel='Year', ylabel='Population',title='Population per country')
# Out:
# <Axes: title={'center': 'Population per country'}, xlabel='Year', ylabel='Population'>

# %% [markdown]
# ### Barplot

# %%
# Selecting only one year.
df_population_1955  = df_population[df_population.index.isin([1955])]
df_population_1955
# Out:
# country  United States        India      Brazil        China       Spain
# year
# 1955.0     171685336.0  409880595.0  62533919.0  612241554.0  29048395.0

# %%
df_population_1955
# Out:
# country  United States        India      Brazil        China       Spain
# year
# 1955.0     171685336.0  409880595.0  62533919.0  612241554.0  29048395.0

# %%
# Bar Plot (without transposing dataframe)
df_population_1955.plot(kind='bar')
# Out:
# <Axes: xlabel='year'>

# %%
# Bar plot with transposing (this is more defined as compared to the non transposed df)
df_population_1955_T = df_population_1955.T
df_population_1955_T
# Out:
# year                1955.0
# country
# United States  171685336.0
# India          409880595.0
# Brazil          62533919.0
# China          612241554.0
# Spain           29048395.0

# %%
df_population_1955_T.plot(kind='bar')
# Out:
# <Axes: xlabel='country'>

# %% [markdown]
# #### bar plot's parameters

# %%
df_population_1955_T.plot(kind='bar', color='blue',xlabel='Country', ylabel='Population',title='Population(1955)')
# Out:
# <Axes: title={'center': 'Population(1955)'}, xlabel='Country', ylabel='Population'>

# %% [markdown]
# ### Bar Graph by  'n' variable

# %%
# df containing only 5 years
df_population_5 = df_population[df_population.index.isin([2000,2005,2010,2015,2020])]

# %%
df_population_5.plot(kind='bar', xlabel='Year', ylabel='Popluation', title='Population (2000-2020)')
# Out:
# <Axes: title={'center': 'Population (2000-2020)'}, xlabel='Year', ylabel='Popluation'>

# %% [markdown]
# ### Pie Chart

# %%
#creating df with year col
df_pie = df_population[df_population.index.isin([1955])]
df_pie_T = df_pie.T

# %%
df_pie_T
# Out:
# year                1955.0
# country
# United States  171685336.0
# India          409880595.0
# Brazil          62533919.0
# China          612241554.0
# Spain           29048395.0

# %%
# renaming object col to string
df_pie_T.rename(columns={1955:'1955'},inplace=True)
df_pie_T.plot(kind='pie', y='1955')
# Out:
# <Axes: ylabel='1955'>

# %% [markdown]
# #### BoxPlot

# %% [markdown]
# Boxplot is a graph that shows us the the data is to spread out. Box plot shows the five important numbers. minimum median and maximum

# %% [markdown]
# ### Single BoxPlot

# %%
df_population['India'].plot(kind='box',ylabel='Population', title='Population in India')
# Out:
# <Axes: title={'center': 'Population in India'}, ylabel='Population'>

# %% [markdown]
#  green line is median, top line tells the maximum number and bottom above india tells the minimum value

# %% [markdown]
# ### Multiple boxplot

# %%
df_population
# Out:
# country  United States         India       Brazil         China       Spain
# year
# 1955.0     171685336.0  4.098806e+08   62533919.0  6.122416e+08  29048395.0
# 1960.0     186720571.0  4.505477e+08   72179226.0  6.604081e+08  30402411.0
# 1965.0     199733676.0  4.991233e+08   83373530.0  7.242190e+08  32146263.0
# 1970.0     209513341.0  5.551898e+08   95113265.0  8.276014e+08  33883749.0
# 1975.0     219081251.0  6.231029e+08  107216205.0  9.262409e+08  35879209.0
# 1980.0     229476354.0  6.989528e+08  120694009.0  1.000089e+09  37698196.0
# 1985.0     240499825.0  7.843600e+08  135274080.0  1.075589e+09  38733876.0
# 1990.0     252120309.0  8.732778e+08  149003223.0  1.176884e+09  39202525.0
# 1995.0     265163745.0  9.639226e+08  162019896.0  1.240921e+09  39787419.0
# 2000.0     281710909.0  1.056576e+09  174790340.0  1.290551e+09  40824754.0
# 2005.0     294993511.0  1.147610e+09  186127103.0  1.330776e+09  44019123.0
# ...

# %%
# making multiple boxplot
df_population.plot(kind='box', color='blue',ylabel='Population', title='Multiple boxplot')
# Out:
# <Axes: title={'center': 'Multiple boxplot'}, ylabel='Population'>

# %% [markdown]
# ### Histogram

# %% [markdown]
# A histogram is a graph that organizes a group of data points into ranges, In the graph, these ranges are represented by vertical bars and they show the frequency of the data

# %%
# histogram for one col
df_population['India'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# histogram for two columns.
df_population[['India','China']].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
